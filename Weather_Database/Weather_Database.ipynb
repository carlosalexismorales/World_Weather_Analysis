# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['grand forks', 'muli', 'guerrero negro', 'sturgeon bay', 'albany', 'vaini', 'cape town', 'faanui', 'lorengau', 'severo-kurilsk'] Generate 759

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1
    
    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0
            
        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand forks
# Processing Record 2 of Set 1 | muli
# Processing Record 3 of Set 1 | guerrero negro
# Processing Record 4 of Set 1 | sturgeon bay
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | lorengau
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | makokou
# Processing Record 18 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 1 | sisophon
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | rovaniemi
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | jhargram
# Processing Record 28 of Set 1 | fare
# Processing Record 29 of Set 1 | ahipara
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | thinadhoo
# Processing Record 32 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 1 | karpathos
# Processing Record 34 of Set 1 | cockburn town
# Processing Record 35 of Set 1 | torquay
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 1 | umea
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | san pedro de macoris
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | caucaia
# Processing Record 45 of Set 1 | yabrud
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | paamiut
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | mumford
# Processing Record 50 of Set 1 | kontagora
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | henties bay
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | san ferdinando di puglia
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | superior
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | brovary
# Processing Record 12 of Set 2 | awjilah
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | sioux lookout
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 2 | kahta
# Processing Record 20 of Set 2 | bunia
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | nanortalik
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 25 of Set 2 | la rochelle
# Processing Record 26 of Set 2 | worgl
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | luba
# Processing Record 30 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 2 | amapa
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | kamaishi
# Processing Record 38 of Set 2 | vardo
# Processing Record 39 of Set 2 | morgan city
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | ormara
# Processing Record 43 of Set 2 | costinesti
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | santarem
# Processing Record 46 of Set 2 | buchanan
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | ixtapa
# Processing Record 3 of Set 3 | sakakah
# Processing Record 4 of Set 3 | marondera
# Processing Record 5 of Set 3 | san rafael
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | troitskiy
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | ruteng
# Processing Record 10 of Set 3 | pemangkat
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | rosita
# Processing Record 13 of Set 3 | tefe
# Processing Record 14 of Set 3 | turukhansk
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | thunder bay
# Processing Record 17 of Set 3 | araouane
# Processing Record 18 of Set 3 | tilichiki
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | nanakuli
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | codrington
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | zeya
# Processing Record 32 of Set 3 | kuito
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | nador
# Processing Record 35 of Set 3 | miri
# Processing Record 36 of Set 3 | meadow lake
# Processing Record 37 of Set 3 | luganville
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | bud
# Processing Record 40 of Set 3 | killybegs
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | woodstock
# Processing Record 43 of Set 3 | grand gaube
# Processing Record 44 of Set 3 | galveston
# Processing Record 45 of Set 3 | tual
# Processing Record 46 of Set 3 | sisimiut
# Processing Record 47 of Set 3 | banda aceh
# Processing Record 48 of Set 3 | wanganui
# Processing Record 49 of Set 3 | albemarle
# Processing Record 50 of Set 3 | morant bay
# Processing Record 1 of Set 4 | merauke
# Processing Record 2 of Set 4 | ramapuram
# Processing Record 3 of Set 4 | heishan
# Processing Record 4 of Set 4 | phuket
# Processing Record 5 of Set 4 | sao felix do xingu
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | katangli
# Processing Record 9 of Set 4 | ilhabela
# Processing Record 10 of Set 4 | vermillion
# Processing Record 11 of Set 4 | itoman
# Processing Record 12 of Set 4 | college
# Processing Record 13 of Set 4 | mithimna
# City not found. Skipping...
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | zhongxing
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | doha
# Processing Record 19 of Set 4 | qaqortoq
# Processing Record 20 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 4 | mount isa
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 4 | bagdarin
# Processing Record 27 of Set 4 | takoradi
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | meulaboh
# Processing Record 30 of Set 4 | amurzet
# Processing Record 31 of Set 4 | dalianwan
# Processing Record 32 of Set 4 | limbang
# Processing Record 33 of Set 4 | fortuna
# Processing Record 34 of Set 4 | pandan
# Processing Record 35 of Set 4 | wawa
# Processing Record 36 of Set 4 | bogoslovka
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | fredericksburg
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | chumikan
# Processing Record 42 of Set 4 | cascais
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | namanga
# Processing Record 45 of Set 4 | norman wells
# Processing Record 46 of Set 4 | hobart
# Processing Record 47 of Set 4 | cayenne
# Processing Record 48 of Set 4 | zavetnoye
# Processing Record 49 of Set 4 | wodonga
# Processing Record 50 of Set 4 | muroto
# Processing Record 1 of Set 5 | zagan
# Processing Record 2 of Set 5 | port alfred
# Processing Record 3 of Set 5 | hue
# Processing Record 4 of Set 5 | garmsar
# Processing Record 5 of Set 5 | khorixas
# Processing Record 6 of Set 5 | skjervoy
# Processing Record 7 of Set 5 | alto araguaia
# Processing Record 8 of Set 5 | lazurne
# Processing Record 9 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 5 | zhanjiang
# Processing Record 13 of Set 5 | general roca
# Processing Record 14 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 5 | gazanjyk
# Processing Record 16 of Set 5 | ohrid
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | peniche
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | alice springs
# Processing Record 22 of Set 5 | todos santos
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 5 | kunming
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | piscu
# Processing Record 29 of Set 5 | puerto carreno
# Processing Record 30 of Set 5 | shenjiamen
# Processing Record 31 of Set 5 | bikaner
# Processing Record 32 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 5 | mehamn
# Processing Record 34 of Set 5 | kisangani
# Processing Record 35 of Set 5 | hirara
# Processing Record 36 of Set 5 | columbia
# Processing Record 37 of Set 5 | esperance
# Processing Record 38 of Set 5 | bambanglipuro
# Processing Record 39 of Set 5 | khamgaon
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | new norfolk
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | lavrentiya
# Processing Record 44 of Set 5 | victor harbor
# Processing Record 45 of Set 5 | eslov
# Processing Record 46 of Set 5 | takaka
# Processing Record 47 of Set 5 | sao filipe
# Processing Record 48 of Set 5 | uruguaiana
# Processing Record 49 of Set 5 | vaitape
# Processing Record 50 of Set 5 | nara
# Processing Record 1 of Set 6 | kampong thum
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | poya
# Processing Record 5 of Set 6 | sao jose da coroa grande
# Processing Record 6 of Set 6 | coburg
# Processing Record 7 of Set 6 | stokmarknes
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 6 | srivardhan
# Processing Record 14 of Set 6 | huilong
# Processing Record 15 of Set 6 | gizo
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | abu dhabi
# Processing Record 18 of Set 6 | kill
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | biltine
# Processing Record 21 of Set 6 | muros
# Processing Record 22 of Set 6 | alekseyevsk
# Processing Record 23 of Set 6 | mulege
# Processing Record 24 of Set 6 | ossora
# Processing Record 25 of Set 6 | humberto de campos
# Processing Record 26 of Set 6 | nemuro
# Processing Record 27 of Set 6 | eyl
# Processing Record 28 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 6 | homer
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | berdigestyakh
# Processing Record 32 of Set 6 | ugoofaaru
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | oktyabrskiy
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | igarka
# Processing Record 38 of Set 6 | nantucket
# Processing Record 39 of Set 6 | saint-francois
# Processing Record 40 of Set 6 | esik
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | ushtobe
# Processing Record 43 of Set 6 | nsanje
# Processing Record 44 of Set 6 | sterling
# Processing Record 45 of Set 6 | berezovyy
# Processing Record 46 of Set 6 | sorkjosen
# Processing Record 47 of Set 6 | mattru
# Processing Record 48 of Set 6 | micomeseng
# Processing Record 49 of Set 6 | padang
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | tawang
# Processing Record 2 of Set 7 | cap malheureux
# Processing Record 3 of Set 7 | pacific grove
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | benidorm
# Processing Record 6 of Set 7 | ahuimanu
# Processing Record 7 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 7 | saint-joseph
# Processing Record 9 of Set 7 | maceio
# Processing Record 10 of Set 7 | damghan
# Processing Record 11 of Set 7 | port hardy
# Processing Record 12 of Set 7 | springfield
# Processing Record 13 of Set 7 | sinnamary
# Processing Record 14 of Set 7 | mastic beach
# Processing Record 15 of Set 7 | necochea
# Processing Record 16 of Set 7 | ondangwa
# Processing Record 17 of Set 7 | la palma
# Processing Record 18 of Set 7 | muncar
# Processing Record 19 of Set 7 | saint-philippe
# Processing Record 20 of Set 7 | pellerd
# Processing Record 21 of Set 7 | alofi
# Processing Record 22 of Set 7 | oranjemund
# Processing Record 23 of Set 7 | kenai
# Processing Record 24 of Set 7 | arinos
# Processing Record 25 of Set 7 | kununurra
# Processing Record 26 of Set 7 | mira
# Processing Record 27 of Set 7 | auki
# Processing Record 28 of Set 7 | mayumba
# Processing Record 29 of Set 7 | busayra
# Processing Record 30 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 31 of Set 7 | mildura
# Processing Record 32 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 33 of Set 7 | jiquilisco
# Processing Record 34 of Set 7 | les cayes
# Processing Record 35 of Set 7 | zhanaozen
# Processing Record 36 of Set 7 | esil
# Processing Record 37 of Set 7 | ambulu
# Processing Record 38 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | pevek
# Processing Record 40 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 7 | maltahohe
# Processing Record 42 of Set 7 | goma
# Processing Record 43 of Set 7 | tsiroanomandidy
# Processing Record 44 of Set 7 | ahero
# Processing Record 45 of Set 7 | formiga
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | shirgaon
# Processing Record 49 of Set 7 | middlebury
# Processing Record 50 of Set 7 | deputatskiy
# Processing Record 1 of Set 8 | mareeba
# Processing Record 2 of Set 8 | igrim
# Processing Record 3 of Set 8 | sivas
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | itarema
# Processing Record 6 of Set 8 | kirakira
# Processing Record 7 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 8 | mogocha
# Processing Record 9 of Set 8 | rantauprapat
# Processing Record 10 of Set 8 | nanticoke
# Processing Record 11 of Set 8 | mezen
# Processing Record 12 of Set 8 | praia da vitoria
# Processing Record 13 of Set 8 | euclides da cunha
# Processing Record 14 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 8 | mountain home
# Processing Record 16 of Set 8 | el alto
# Processing Record 17 of Set 8 | northam
# Processing Record 18 of Set 8 | rocha
# Processing Record 19 of Set 8 | kieta
# Processing Record 20 of Set 8 | flagstaff
# Processing Record 21 of Set 8 | martin
# Processing Record 22 of Set 8 | pokhara
# Processing Record 23 of Set 8 | flinders
# Processing Record 24 of Set 8 | bernburg
# Processing Record 25 of Set 8 | lashio
# Processing Record 26 of Set 8 | fukue
# Processing Record 27 of Set 8 | aden
# Processing Record 28 of Set 8 | khash
# Processing Record 29 of Set 8 | zaysan
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | alta floresta
# Processing Record 32 of Set 8 | taltal
# Processing Record 33 of Set 8 | rock sound
# Processing Record 34 of Set 8 | kenora
# Processing Record 35 of Set 8 | kloulklubed
# Processing Record 36 of Set 8 | huarmey
# Processing Record 37 of Set 8 | narsaq
# Processing Record 38 of Set 8 | pabrade
# Processing Record 39 of Set 8 | klaksvik
# Processing Record 40 of Set 8 | chaohu
# Processing Record 41 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 42 of Set 8 | ringkobing
# Processing Record 43 of Set 8 | baykit
# Processing Record 44 of Set 8 | arecibo
# Processing Record 45 of Set 8 | bereznik
# Processing Record 46 of Set 8 | hun
# Processing Record 47 of Set 8 | arraial do cabo
# Processing Record 48 of Set 8 | umm lajj
# Processing Record 49 of Set 8 | qaanaaq
# Processing Record 50 of Set 8 | tiznit
# Processing Record 1 of Set 9 | egvekinot
# Processing Record 2 of Set 9 | zabaykalsk
# Processing Record 3 of Set 9 | dandong
# Processing Record 4 of Set 9 | iquitos
# Processing Record 5 of Set 9 | mehran
# Processing Record 6 of Set 9 | ankang
# Processing Record 7 of Set 9 | sint-gillis-waas
# Processing Record 8 of Set 9 | concordia
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | rosarito
# Processing Record 11 of Set 9 | lavumisa
# Processing Record 12 of Set 9 | grafton
# Processing Record 13 of Set 9 | lamu
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | vostok
# Processing Record 16 of Set 9 | mbanza-ngungu
# Processing Record 17 of Set 9 | camacari
# Processing Record 18 of Set 9 | acapulco
# Processing Record 19 of Set 9 | noumea
# Processing Record 20 of Set 9 | kysyl-syr
# Processing Record 21 of Set 9 | torit
# Processing Record 22 of Set 9 | addi ugri
# City not found. Skipping...
# Processing Record 23 of Set 9 | temerloh
# Processing Record 24 of Set 9 | eureka
# Processing Record 25 of Set 9 | billings
# Processing Record 26 of Set 9 | santa maria
# Processing Record 27 of Set 9 | bida
# Processing Record 28 of Set 9 | asfi
# Processing Record 29 of Set 9 | portland
# Processing Record 30 of Set 9 | rio gallegos
# Processing Record 31 of Set 9 | rawah
# Processing Record 32 of Set 9 | nabire
# Processing Record 33 of Set 9 | gamba
# Processing Record 34 of Set 9 | dingle
# Processing Record 35 of Set 9 | faya
# Processing Record 36 of Set 9 | puerto el triunfo
# Processing Record 37 of Set 9 | mercedes
# Processing Record 38 of Set 9 | batemans bay
# Processing Record 39 of Set 9 | quatre cocos
# Processing Record 40 of Set 9 | norfolk
# Processing Record 41 of Set 9 | itacare
# Processing Record 42 of Set 9 | mackay
# Processing Record 43 of Set 9 | maldonado
# Processing Record 44 of Set 9 | yaan
# Processing Record 45 of Set 9 | gallup
# Processing Record 46 of Set 9 | mandera
# Processing Record 47 of Set 9 | buala
# Processing Record 48 of Set 9 | marawi
# Processing Record 49 of Set 9 | nizwa
# Processing Record 50 of Set 9 | hot springs
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 10 | trabzon
# Processing Record 4 of Set 10 | bandrele
# Processing Record 5 of Set 10 | bayan
# Processing Record 6 of Set 10 | evensk
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | sendafa
# Processing Record 9 of Set 10 | port-gentil
# Processing Record 10 of Set 10 | mangrol
# Processing Record 11 of Set 10 | kedrovyy
# Processing Record 12 of Set 10 | half moon bay
# Processing Record 13 of Set 10 | benghazi
# Processing Record 14 of Set 10 | birjand
# Processing Record 15 of Set 10 | kingori
# Processing Record 16 of Set 10 | katete
# Processing Record 17 of Set 10 | porto velho
# Processing Record 18 of Set 10 | bria
# Processing Record 19 of Set 10 | boddam
# Processing Record 20 of Set 10 | margate
# Processing Record 21 of Set 10 | chernyshevskiy
# Processing Record 22 of Set 10 | linqing
# Processing Record 23 of Set 10 | tautira
# Processing Record 24 of Set 10 | leningradskiy
# Processing Record 25 of Set 10 | berlevag
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | brito
# Processing Record 28 of Set 10 | killin
# Processing Record 29 of Set 10 | vila
# Processing Record 30 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 10 | north bend
# Processing Record 32 of Set 10 | krasnogorodsk
# Processing Record 33 of Set 10 | jiuquan
# Processing Record 34 of Set 10 | toumodi
# Processing Record 35 of Set 10 | poopo
# Processing Record 36 of Set 10 | gwanda
# Processing Record 37 of Set 10 | rabaul
# Processing Record 38 of Set 10 | nampa
# Processing Record 39 of Set 10 | pavlodar
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | san juan de flores
# Processing Record 42 of Set 10 | puerto madryn
# Processing Record 43 of Set 10 | xiuyan
# Processing Record 44 of Set 10 | fort-shevchenko
# Processing Record 45 of Set 10 | laurinburg
# Processing Record 46 of Set 10 | bandarbeyla
# Processing Record 47 of Set 10 | kismayo
# Processing Record 48 of Set 10 | kyra
# Processing Record 49 of Set 10 | magadi
# Processing Record 50 of Set 10 | lufilufi
# Processing Record 1 of Set 11 | nowa ruda
# Processing Record 2 of Set 11 | kristiansund
# Processing Record 3 of Set 11 | aripuana
# Processing Record 4 of Set 11 | vila velha
# Processing Record 5 of Set 11 | hami
# Processing Record 6 of Set 11 | kurchum
# Processing Record 7 of Set 11 | omemee
# Processing Record 8 of Set 11 | kutum
# Processing Record 9 of Set 11 | north platte
# Processing Record 10 of Set 11 | cervo
# Processing Record 11 of Set 11 | jalu
# Processing Record 12 of Set 11 | camana
# Processing Record 13 of Set 11 | chipinge
# Processing Record 14 of Set 11 | druzhba
# Processing Record 15 of Set 11 | makaha
# Processing Record 16 of Set 11 | coihaique
# Processing Record 17 of Set 11 | mayo
# Processing Record 18 of Set 11 | tirumullaivasal
# Processing Record 19 of Set 11 | motygino
# Processing Record 20 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 21 of Set 11 | la ronge
# Processing Record 22 of Set 11 | lakatoro
# Processing Record 23 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 11 | pedasi
# Processing Record 25 of Set 11 | rapid valley
# Processing Record 26 of Set 11 | luderitz
# Processing Record 27 of Set 11 | pasni
# Processing Record 28 of Set 11 | aguimes
# Processing Record 29 of Set 11 | avera
# Processing Record 30 of Set 11 | rome
# Processing Record 31 of Set 11 | uzunkopru
# City not found. Skipping...
# Processing Record 32 of Set 11 | boyolangu
# Processing Record 33 of Set 11 | shakawe
# Processing Record 34 of Set 11 | isangel
# Processing Record 35 of Set 11 | gaya
# Processing Record 36 of Set 11 | tamworth
# Processing Record 37 of Set 11 | rawson
# Processing Record 38 of Set 11 | calbuco
# Processing Record 39 of Set 11 | songjianghe
# Processing Record 40 of Set 11 | chardara
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | chamalieres
# Processing Record 43 of Set 11 | ulagan
# Processing Record 44 of Set 11 | abu samrah
# Processing Record 45 of Set 11 | milkovo
# Processing Record 46 of Set 11 | gornopravdinsk
# Processing Record 47 of Set 11 | azar shahr
# City not found. Skipping...
# Processing Record 48 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 49 of Set 11 | shimanovsk
# Processing Record 50 of Set 11 | shubarshi
# Processing Record 1 of Set 12 | sohag
# Processing Record 2 of Set 12 | lata
# Processing Record 3 of Set 12 | tello
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | leh
# Processing Record 6 of Set 12 | cururupu
# Processing Record 7 of Set 12 | hamilton
# Processing Record 8 of Set 12 | valparaiso
# Processing Record 9 of Set 12 | hope
# Processing Record 10 of Set 12 | opuwo
# Processing Record 11 of Set 12 | guarapari
# Processing Record 12 of Set 12 | wenling
# Processing Record 13 of Set 12 | inuvik
# Processing Record 14 of Set 12 | tura
# Processing Record 15 of Set 12 | suamico
# Processing Record 16 of Set 12 | milpitas
# Processing Record 17 of Set 12 | palmer
# Processing Record 18 of Set 12 | vao
# Processing Record 19 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 12 | stornoway
# Processing Record 21 of Set 12 | sao joao da barra
# Processing Record 22 of Set 12 | westport
# Processing Record 23 of Set 12 | itaituba
# Processing Record 24 of Set 12 | yangjiang
# Processing Record 25 of Set 12 | bogorodskoye
# Processing Record 26 of Set 12 | bjelovar
# Processing Record 27 of Set 12 | ampanihy
# Processing Record 28 of Set 12 | komsomolskiy
# Processing Record 29 of Set 12 | victoria point
# Processing Record 30 of Set 12 | grado
# Processing Record 31 of Set 12 | raymondville
# Processing Record 32 of Set 12 | sorland
# Processing Record 33 of Set 12 | nadvoitsy
# Processing Record 34 of Set 12 | oum hadjer
# Processing Record 35 of Set 12 | kahului
# Processing Record 36 of Set 12 | soledade
# Processing Record 37 of Set 12 | bayangol
# Processing Record 38 of Set 12 | khrustalnyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | balfour
# Processing Record 40 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 12 | kuldiga
# Processing Record 42 of Set 12 | vanavara
# Processing Record 43 of Set 12 | safaga
# Processing Record 44 of Set 12 | dharchula
# Processing Record 45 of Set 12 | cookeville
# Processing Record 46 of Set 12 | pathein
# Processing Record 47 of Set 12 | iskateley
# Processing Record 48 of Set 12 | the pas
# Processing Record 49 of Set 12 | mabaruma
# Processing Record 50 of Set 12 | abong mbang
# Processing Record 1 of Set 13 | ciudad bolivar
# Processing Record 2 of Set 13 | vangaindrano
# Processing Record 3 of Set 13 | bonthe
# Processing Record 4 of Set 13 | riosucio
# Processing Record 5 of Set 13 | grindavik
# Processing Record 6 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 13 | coxim
# Processing Record 8 of Set 13 | acajutla
# Processing Record 9 of Set 13 | troitskoye
# Processing Record 10 of Set 13 | nagato
# Processing Record 11 of Set 13 | beidao
# Processing Record 12 of Set 13 | khuzdar
# Processing Record 13 of Set 13 | newport
# Processing Record 14 of Set 13 | solano
# Processing Record 15 of Set 13 | berbera
# Processing Record 16 of Set 13 | bay-khaak
# Processing Record 17 of Set 13 | santa eulalia
# Processing Record 18 of Set 13 | katobu
# Processing Record 19 of Set 13 | nouadhibou
# Processing Record 20 of Set 13 | kolokani
# Processing Record 21 of Set 13 | neiafu
# Processing Record 22 of Set 13 | puerto penasco
# Processing Record 23 of Set 13 | souillac
# Processing Record 24 of Set 13 | bekhtery
# Processing Record 25 of Set 13 | yar-sale
# Processing Record 26 of Set 13 | brae
# Processing Record 27 of Set 13 | ulladulla
# Processing Record 28 of Set 13 | danshui
# Processing Record 29 of Set 13 | kirkwall
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | piltene
# Processing Record 32 of Set 13 | uige
# Processing Record 33 of Set 13 | rafiganj
# Processing Record 34 of Set 13 | purranque
# Processing Record 35 of Set 13 | tupik
# Processing Record 36 of Set 13 | bone
# Processing Record 37 of Set 13 | mount gambier
# Processing Record 38 of Set 13 | zhuanghe
# Processing Record 39 of Set 13 | rockhampton
# Processing Record 40 of Set 13 | zehdenick
# Processing Record 41 of Set 13 | carlsbad
# Processing Record 42 of Set 13 | santa marta
# Processing Record 43 of Set 13 | vostochnyy
# Processing Record 44 of Set 13 | boende
# Processing Record 45 of Set 13 | voh
# Processing Record 46 of Set 13 | zakamensk
# Processing Record 47 of Set 13 | lasa
# Processing Record 48 of Set 13 | bakhtiyarpur
# Processing Record 49 of Set 13 | kirgiz-miyaki
# Processing Record 50 of Set 13 | chapleau
# Processing Record 1 of Set 14 | nelson bay
# Processing Record 2 of Set 14 | machali
# Processing Record 3 of Set 14 | le vauclin
# Processing Record 4 of Set 14 | nortelandia
# Processing Record 5 of Set 14 | nuuk
# Processing Record 6 of Set 14 | gerash
# Processing Record 7 of Set 14 | camargo
# Processing Record 8 of Set 14 | ketchikan
# Processing Record 9 of Set 14 | santa cruz
# Processing Record 10 of Set 14 | sola
# Processing Record 11 of Set 14 | tezu
# Processing Record 12 of Set 14 | bowen
# Processing Record 13 of Set 14 | oksfjord
# Processing Record 14 of Set 14 | urucui
# Processing Record 15 of Set 14 | kuusamo
# Processing Record 16 of Set 14 | aktau
# Processing Record 17 of Set 14 | canico
# Processing Record 18 of Set 14 | moron
# Processing Record 19 of Set 14 | tayu
# Processing Record 20 of Set 14 | kodinsk
# Processing Record 21 of Set 14 | santa teresa
# Processing Record 22 of Set 14 | pilas
# Processing Record 23 of Set 14 | kamalia
# Processing Record 24 of Set 14 | vrangel
# Processing Record 25 of Set 14 | lalmohan
# Processing Record 26 of Set 14 | goure
# Processing Record 27 of Set 14 | tsaritsani
# Processing Record 28 of Set 14 | slave lake
# Processing Record 29 of Set 14 | srednekolymsk
# Processing Record 30 of Set 14 | terra santa
# Processing Record 31 of Set 14 | puerto baquerizo moreno
# Processing Record 32 of Set 14 | svetlaya
# Processing Record 33 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 14 | licheng
# Processing Record 35 of Set 14 | gatton
# Processing Record 36 of Set 14 | birao
# Processing Record 37 of Set 14 | ranong
# Processing Record 38 of Set 14 | vuktyl
# Processing Record 39 of Set 14 | the valley
# Processing Record 40 of Set 14 | sechura
# Processing Record 41 of Set 14 | kropotkin
# Processing Record 42 of Set 14 | trindade
# Processing Record 43 of Set 14 | mahon
# Processing Record 44 of Set 14 | goderich
# Processing Record 45 of Set 14 | mrakovo
# Processing Record 46 of Set 14 | waipawa
# Processing Record 47 of Set 14 | huanren
# Processing Record 48 of Set 14 | knysna
# Processing Record 49 of Set 14 | san isidro
# Processing Record 50 of Set 14 | tukrah
# Processing Record 1 of Set 15 | murgab
# Processing Record 2 of Set 15 | ulaanbaatar
# Processing Record 3 of Set 15 | san vicente
# Processing Record 4 of Set 15 | shakhta
# Processing Record 5 of Set 15 | karratha
# Processing Record 6 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 15 | trunovskoye
# Processing Record 8 of Set 15 | igarape-acu
# City not found. Skipping...
# Processing Record 9 of Set 15 | riyadh
# Processing Record 10 of Set 15 | moses lake
# Processing Record 11 of Set 15 | presidencia roque saenz pena
# Processing Record 12 of Set 15 | ayan
# Processing Record 13 of Set 15 | labuhan
# Processing Record 14 of Set 15 | brokopondo
# Processing Record 15 of Set 15 | salinas
# Processing Record 16 of Set 15 | ribeira brava
# Processing Record 17 of Set 15 | yei
# Processing Record 18 of Set 15 | nichinan
# Processing Record 19 of Set 15 | jaen
# Processing Record 20 of Set 15 | morondava
# Processing Record 21 of Set 15 | port blair
# Processing Record 22 of Set 15 | tankhoy
# Processing Record 23 of Set 15 | antofagasta
# Processing Record 24 of Set 15 | yerofey pavlovich
# Processing Record 25 of Set 15 | bilibino
# Processing Record 26 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 15 | vicuna
# Processing Record 28 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 15 | pochutla
# Processing Record 30 of Set 15 | cap-aux-meules
# Processing Record 31 of Set 15 | galle
# Processing Record 32 of Set 15 | zhigansk
# Processing Record 33 of Set 15 | nuevo progreso
# Processing Record 34 of Set 15 | sarwar
# Processing Record 35 of Set 15 | rio grande
# Processing Record 36 of Set 15 | bosaso
# Processing Record 37 of Set 15 | altay
# Processing Record 38 of Set 15 | mitu
# Processing Record 39 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 41 of Set 15 | san matias
# Processing Record 42 of Set 15 | ancud
# Processing Record 43 of Set 15 | stribro
# Processing Record 44 of Set 15 | itupiranga
# Processing Record 45 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 46 of Set 15 | comodoro rivadavia
# Processing Record 47 of Set 15 | clinton
# Processing Record 48 of Set 15 | eyrarbakki
# Processing Record 49 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 15 | idritsa
# Processing Record 1 of Set 16 | namatanai
# Processing Record 2 of Set 16 | aykhal
# Processing Record 3 of Set 16 | khudumelapye
# Processing Record 4 of Set 16 | makakilo city
# Processing Record 5 of Set 16 | pimentel
# Processing Record 6 of Set 16 | san pedro
# Processing Record 7 of Set 16 | pombas
# Processing Record 8 of Set 16 | mogadishu
# Processing Record 9 of Set 16 | honningsvag
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 701

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0     grand forks      US  2022-07-05 04:00:21  47.9417  -97.4337     69.73
# 1            muli      MV  2022-07-05 04:02:39   2.9167   73.5667     82.89
# 2  guerrero negro      MX  2022-07-05 03:59:06  27.9769 -114.0611     65.41
# 3    sturgeon bay      US  2022-07-05 03:57:44  44.8342  -87.3770     66.18
# 4          albany      US  2022-07-05 03:58:03  42.6001  -73.9662     65.73
# 5           vaini      TO  2022-07-05 04:02:39 -21.2000 -175.2000     72.91
# 6       cape town      ZA  2022-07-05 04:02:40 -33.9258   18.4232     55.90
# 7          faanui      PF  2022-07-05 04:02:40 -16.4833 -151.7500     79.07
# 8        lorengau      PG  2022-07-05 04:02:41  -2.0226  147.2712     85.21
# 9  severo-kurilsk      RU  2022-07-05 04:02:41  50.6789  156.1250     55.98
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        94         100        6.91     overcast clouds
# 1        75          86       10.00     overcast clouds
# 2        82           0       19.44           clear sky
# 3       100         100        4.61     overcast clouds
# 4        74          89        3.06     overcast clouds
# 5        71         100       25.99     overcast clouds
# 6        79           0       11.01           clear sky
# 7        73          40        9.42          light rain
# 8        68          64        6.40       broken clouds
# 9        74          85       12.35     overcast clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                       0.0                         0
# 1                       0.0                         0
# 2                       0.0                         0
# 3                       0.0                         0
# 4                       0.0                         0
# 5                       0.0                         0
# 6                       0.0                         0
# 7                       0.0                         0
# 8                       0.0                         0
# 9                       0.0                         0

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='Weather_Database/WeatherPy_Database.csv', index_label='City_ID')
