# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID               City Coounty                 Date      Lat       Lng  \
# 0        0      mount gambier      AU  2022-07-04 04:11:08 -37.8333  140.7667
# 1        1              bajil      YE  2022-07-04 04:11:08  15.0584   43.2851
# 2        2          busselton      AU  2022-07-04 04:11:09 -33.6500  115.3333
# 3        3          carnarvon      AU  2022-07-04 04:11:09 -24.8667  113.6333
# 4        4  belaya kholunitsa      RU  2022-07-04 04:11:10  58.8400   50.8528
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     58.75        64          81        8.86
# 1     85.51        67          51        7.09
# 2     62.58        56           0       22.39
# 3     67.84        27           0       16.80
# 4     56.35        63          83        8.77

# %%
# Get the data types 
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Coounty        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Percent Humidity Heatmap
locations = city_data_df[['Lat','Lng']]
humidity = city_data_df['Humidity']

heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity,
                            dissipating = False, max_intensity=300, point_radius=4)
fig = gmaps.figure(center=(30.0,31.0), zoom_level = 1.5)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Percent Cloudiness Heatmap
locations = city_data_df[['Lat','Lng']]
clouds = city_data_df['Cloudiness']

heatmap_layer = gmaps.heatmap_layer(locations,weights=clouds,
                    dissipating=False, max_intensity=300, point_radius=4)
fig = gmaps.figure(center = (30.0,31.0), zoom_level =1.5)
fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Wind Speed Heatmap
locations = city_data_df[['Lat','Lng']]
wind = city_data_df['Wind Speed']

heatmap_layer = gmaps.heatmap_layer(locations, weights=wind,
                            dissipating = False, max_intensity=300, point_radius=4)
fig = gmaps.figure(center=(30.0,31.0), zoom_level = 1.5)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID           City Coounty                 Date      Lat       Lng  \
# 1         1          bajil      YE  2022-07-04 04:11:08  15.0584   43.2851
# 5         5        rikitea      PF  2022-07-04 04:11:10 -23.1203 -134.9692
# 22       22       tomatlan      MX  2022-07-04 04:11:17  19.9333 -105.2500
# 26       26     georgetown      MY  2022-07-04 04:06:36   5.4112  100.3354
# 28       28       khargone      IN  2022-07-04 04:11:21  21.8167   75.6000
# 30       30  san cristobal      VE  2022-07-04 04:11:22   7.7669  -72.2250
# 32       32      kavaratti      IN  2022-07-04 04:11:22  10.5669   72.6420
# 34       34      hithadhoo      MV  2022-07-04 04:11:23  -0.6000   73.0833
# 35       35            ola      RU  2022-07-04 04:11:24  59.5833  151.2833
# 37       37       victoria      HK  2022-07-04 04:08:38  22.2855  114.1577
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      85.51        67          51        7.09
# 5      75.22        71           1       14.81
# 22     76.77        88          62        1.61
# 26     89.89        60          20        6.91
# 28     79.90        80         100        8.19
# 30     75.38        98          80        4.00
# 32     81.99        79         100       19.71
# 34     83.05        74         100        7.72
# 35     77.14        67         100        2.19
# 37     84.96        86         100       21.00

# %%
preferred_cities_df.count()
# Out:
# City_ID       187
# City          187
# Coounty       187
# Date          187
# Lat           187
# Lng           187
# Max Temp      187
# Humidity      187
# Cloudiness    187
# Wind Speed    187
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Coounty", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Coounty  Max Temp      Lat       Lng Hotel Name
# 1           bajil      YE     85.51  15.0584   43.2851
# 5         rikitea      PF     75.22 -23.1203 -134.9692
# 22       tomatlan      MX     76.77  19.9333 -105.2500
# 26     georgetown      MY     89.89   5.4112  100.3354
# 28       khargone      IN     79.90  21.8167   75.6000
# 30  san cristobal      VE     75.38   7.7669  -72.2250
# 32      kavaratti      IN     81.99  10.5669   72.6420
# 34      hithadhoo      MV     83.05  -0.6000   73.0833
# 35            ola      RU     77.14  59.5833  151.2833
# 37       victoria      HK     84.96  22.2855  114.1577

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
# Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
hotel_df.head(10)
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#              City Coounty  Max Temp      Lat       Lng  \
# 1           bajil      YE     85.51  15.0584   43.2851
# 5         rikitea      PF     75.22 -23.1203 -134.9692
# 22       tomatlan      MX     76.77  19.9333 -105.2500
# 26     georgetown      MY     89.89   5.4112  100.3354
# 28       khargone      IN     79.90  21.8167   75.6000
# 30  san cristobal      VE     75.38   7.7669  -72.2250
# 32      kavaratti      IN     81.99  10.5669   72.6420
# 34      hithadhoo      MV     83.05  -0.6000   73.0833
# 35            ola      RU     77.14  59.5833  151.2833
# 37       victoria      HK     84.96  22.2855  114.1577
#
#                        Hotel Name
# 1                     فندق حضرموت
# 5                 People ThankYou
# 22                     El Salvial
# 26                 Cititel Penang
# 28   SPOT ON 63187 Vallabha Hotel
# 30                       Pirineos
# 32  Hotels in Lakshadweep Islands
# 34              Scoop Guest House
# 35
# 37                   Mini Central

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Coounty</dt><dd>{Coounty}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
